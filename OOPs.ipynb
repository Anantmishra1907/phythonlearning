# %% [markdown]
# <a href="https://colab.research.google.com/github/Anantmishra1907/phythonlearning/blob/main/OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Dog:
    species = "Canine"  # Class attribute
#__init__ method: Initializes the name and age attributes when a new object is created.
    def __init__(self, name, age):
        self.name = name  # Instance attribute
        self.age = age  # Instance attribute

# %%
dog1 = Dog("Buddy", 3)
dog2 = Dog("Molly", 2)

# %%
print(dog1.name, dog1.age)
print(dog2.name, dog2.age)
# Out:
# Buddy 3
# Molly 2

# %%
#__init__ Method

#__init__ method is the constructor in Python, automatically called when a new object is created. It initializes the attributes of the class.

# %%
class dog :
  def __init__(self , name , age ):
      self.name = name
      self.age = age
  print(dog1.name, dog1.age)
  print(dog2.name, dog2.age)
# Out:
# Buddy 3
# Molly 2

# %%
## Class and Insttance Variable
class Dog:
    # Class variable
    species = "Canine"

    def __init__(self, name, age):
        # Instance variables
        self.name = name
        self.age = age

# Create objects
dog1 = Dog("Buddy", 3)
dog2 = Dog("Charlie", 5)

# Access class and instance variables
print(dog1.species)  # (Class variable)
print(dog1.name)     # (Instance variable)
print(dog2.name)     # (Instance variable)

# Modify instance variables
dog1.name = "Max"
print(dog1.name)     # (Updated instance variable)

# Modify class variable
Dog.species = "Feline"
print(dog1.species)  # (Updated class variable)
print(dog2.species)
# Out:
# Canine
# Buddy
# Charlie
# Max
# Feline
# Feline
