# %% [markdown]
# <a href="https://colab.research.google.com/github/Anantmishra1907/phythonlearning/blob/main/python3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Functions

# %%
def fun():
  print("Welcome to the functions present there")
fun()
# Out:
# Welcome to the functions present there

# %%
# even and odd function
def evenodd(x):
  if(x % 2 == 0):
    print("Even")
  else:
    print("Odd")
evenodd(2)
evenodd(3)
# Out:
# Even
# Odd

# %%
#default argument : uses predefined value , when no value is passed through it

# %%
def default(x , y = 50):
  print("x ", x)
  print("y ", y)
default(30 , 40)
default(40)
# Out:
# x  30
# y  40
# x  40
# y  50

# %%
# keyword argument : defiend during the the giving the value to it

# %%
def student(fname, lname):
    print(fname, lname)

student(fname='Anant', lname='Practice')
student(lname='Practice', fname='Anant')
# Out:
# Anant Practice
# Anant Practice

# %%
# posiition Argument : depends upon the given p[ositon

# %%
def nameAge(name, age):
    print("Hi, I am", name)
    print("My age is ", age)

print("Case-1:")
nameAge("Olivia", 27)

print("Case-2:")
nameAge(27, "Olivia")
# Out:
# Case-1:
# Hi, I am Olivia
# My age is  27
# Case-2:
# Hi, I am 27
# My age is  Olivia

# %% [markdown]
# Arbitrary Arguments: allow functions to accept multiple values. This is done using two special symbols:
#
# *args collects extra positional arguments as a tuple.
# **kwargs collects extra keyword arguments as a dictionary.

# %%
def myFun(*args, **kwargs):
    print("Non-Keyword Arguments (*args):")
    for arg in args:
        print(arg)

    print("Keyword Arguments (**kwargs):")
    for key, value in kwargs.items():
        print(f"{key} == {value}")

myFun('Hey', 'Welcome', first='Geeks', mid='for', last='Geeks')
# Out:
# Non-Keyword Arguments (*args):
# Hey
# Welcome
# Keyword Arguments (**kwargs):
# first == Geeks
# mid == for
# last == Geeks

# %% [markdown]
# Lambda functions are small anonymous functions, meaning they do not have a defined name. These are small, short-lived functions used to pass simple logic to another function.
#
# Contain only one expression.
# Result of that expression is returned automatically (no return keyword needed).

# %%
a = lambda x: x**2
print(a(3))
# Out:
# 9
